# %% [markdown]
# <a href="https://colab.research.google.com/github/1234567890qqqqqq/bsc_dpdm22/blob/main/%5Bdataprep3%5D_Discretization_Normalization_One_hot_Encoder.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Normalization-Standardization
# https://scikit-learn.org/stable/modules/preprocessing.html#scaling-features-to-a-range

# %%
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ## ใช้ data กรมอุตุ

# %%
weather_data = pd.read_csv('/content/drive/MyDrive/2 65/จารต้น 2/bsc_DMPM_data/GroupQuiz1/Group7_17ธนภรณ์_19นารากร_20สุริยา_35อรัญญา.csv')

# %%
weather_data.shape
# Out:
# (8169, 20)

# %%
weather_data.head()
# Out:
#    จังหวัด  วันที่  เดือน    ปี               สถานีความกด  \
# 0  ขอนแก่น       1     10  2011  352201-หนองคาย จ.หนองคาย
# 1  ขอนแก่น       2     10  2011  352201-หนองคาย จ.หนองคาย
# 2  ขอนแก่น       3     10  2011  352201-หนองคาย จ.หนองคาย
# 3  ขอนแก่น       4     10  2011  352201-หนองคาย จ.หนองคาย
# 4  ขอนแก่น       5     10  2011  352201-หนองคาย จ.หนองคาย
#
#       สถานีความชื้นสัมพัทธ์     สถานีอุณหภูมิตุ้มแห้ง  \
# 0  381201-ขอนแก่น จ.ขอนแก่น  381201-ขอนแก่น จ.ขอนแก่น
# 1  381201-ขอนแก่น จ.ขอนแก่น  381201-ขอนแก่น จ.ขอนแก่น
# 2  381201-ขอนแก่น จ.ขอนแก่น  381201-ขอนแก่น จ.ขอนแก่น
# 3  381201-ขอนแก่น จ.ขอนแก่น  381201-ขอนแก่น จ.ขอนแก่น
# 4  381201-ขอนแก่น จ.ขอนแก่น  381201-ขอนแก่น จ.ขอนแก่น
#
#     สถานีอุณหภูมิจุดน้ำค้าง       สถานีอุณหภูมิต่ำสุด          สถานีจำนวนเมฆ  \
# 0  381201-ขอนแก่น จ.ขอนแก่น  381201-ขอนแก่น จ.ขอนแก่น  353301-เลย สกษ. จ.เลย
# 1  381201-ขอนแก่น จ.ขอนแก่น  381201-ขอนแก่น จ.ขอนแก่น  353301-เลย สกษ. จ.เลย
# ...

# %%
data_features = weather_data.iloc[ :,12:]
data_features.head()
# Out:
#     ความกด  ความชื้นสัมพัทธ์  อุณหภูมิตุ้มแห้ง  อุณหภูมิจุดน้ำค้าง  \
# 0  1005.47                83              27.6                24.2
# 1  1006.65                92              25.6                24.0
# 2  1007.49                86              25.6                22.9
# 3  1008.28                80              25.8                21.9
# 4  1009.88                86              24.3                21.7
#
#   อุณหภูมิต่ำสุด จำนวนเมฆ ปริมาณฝน ความเร็วลม
# 0           24.8        9      1.4          3
# 1           23.0       10     17.7          2
# 2           22.1       10        3          3
# 3           22.8        8        0          2
# 4           23.1       10      2.2          2

# %%
data_features.describe()
# Out:
#             ความกด  ความชื้นสัมพัทธ์  อุณหภูมิตุ้มแห้ง  อุณหภูมิจุดน้ำค้าง
# count  8169.000000       8169.000000       8169.000000         8169.000000
# mean   1013.016946         69.798262         24.868405           18.151916
# std       3.224640          8.870501          2.846185            3.775475
# min    1002.040000         38.000000         11.800000            1.500000
# 25%    1010.960000         64.000000         23.300000           15.800000
# 50%    1012.800000         69.000000         25.300000           18.400000
# 75%    1015.010000         75.000000         27.000000           21.000000
# max    1026.100000         99.000000         31.000000           28.400000

# %%
data_features.dtypes
# Out:
# ความกด                float64
# ความชื้นสัมพัทธ์        int64
# อุณหภูมิตุ้มแห้ง      float64
# อุณหภูมิจุดน้ำค้าง    float64
# อุณหภูมิต่ำสุด         object
# จำนวนเมฆ               object
# ปริมาณฝน               object
# ความเร็วลม             object
# dtype: object

# %%
weather_data[weather_data.eq('-').any(1)]
# Out:
#       จังหวัด  วันที่  เดือน    ปี               สถานีความกด  \
# 305   ขอนแก่น       3     10  2013  352201-หนองคาย จ.หนองคาย
# 306   ขอนแก่น       4     10  2013  352201-หนองคาย จ.หนองคาย
# 307   ขอนแก่น       5     10  2013  352201-หนองคาย จ.หนองคาย
# 308   ขอนแก่น       6     10  2013  352201-หนองคาย จ.หนองคาย
# 309   ขอนแก่น       7     10  2013  352201-หนองคาย จ.หนองคาย
# ...       ...     ...    ...   ...                       ...
# 8134      เลย      25      1  2021  352201-หนองคาย จ.หนองคาย
# 8135      เลย      26      1  2021  352201-หนองคาย จ.หนองคาย
# 8140      เลย      31      1  2021  352201-หนองคาย จ.หนองคาย
# 8161      เลย      21      2  2021  352201-หนองคาย จ.หนองคาย
# 8162      เลย      22      2  2021  352201-หนองคาย จ.หนองคาย
#
#          สถานีความชื้นสัมพัทธ์     สถานีอุณหภูมิตุ้มแห้ง  \
# 305   381201-ขอนแก่น จ.ขอนแก่น  381201-ขอนแก่น จ.ขอนแก่น
# 306   381201-ขอนแก่น จ.ขอนแก่น  381201-ขอนแก่น จ.ขอนแก่น
# 307   381201-ขอนแก่น จ.ขอนแก่น  381201-ขอนแก่น จ.ขอนแก่น
# ...

# %%
weather_data[weather_data['ความเร็วลม'].eq('-')]
# Out:
#       จังหวัด  วันที่  เดือน    ปี               สถานีความกด  \
# 1079  ขอนแก่น      21     10  2018  352201-หนองคาย จ.หนองคาย
# 1122  ขอนแก่น       3     12  2018  352201-หนองคาย จ.หนองคาย
# 1773   นครพนม      18      1  2012  352201-หนองคาย จ.หนองคาย
# 1776   นครพนม      21      1  2012  352201-หนองคาย จ.หนองคาย
# 1856   นครพนม      10     11  2012  352201-หนองคาย จ.หนองคาย
# 1862   นครพนม      16     11  2012  352201-หนองคาย จ.หนองคาย
# 1927   นครพนม      20      1  2013  352201-หนองคาย จ.หนองคาย
# 1995   นครพนม      29     10  2013  352201-หนองคาย จ.หนองคาย
# 2063   นครพนม       5      1  2014  352201-หนองคาย จ.หนองคาย
# 2125   นครพนม       8     10  2014  352201-หนองคาย จ.หนองคาย
# 2172   นครพนม      24     11  2014  352201-หนองคาย จ.หนองคาย
# 2173   นครพนม      25     11  2014  352201-หนองคาย จ.หนองคาย
# 2176   นครพนม      28     11  2014  352201-หนองคาย จ.หนองคาย
# 2523   นครพนม      11      1  2017  352201-หนองคาย จ.หนองคาย
# ...

# %%
data_features_d = data_features[data_features.eq('-').any(1)==False]
data_features_d.shape
# Out:
# (5208, 8)

# %%
data_features_d = data_features_d[data_features_d.eq('T').any(1)==False]
data_features_d.shape
# Out:
# (5061, 8)

# %% [markdown]
# ### แปลงให้เป็นตัวเลข

# %%
data_features_d['ความเร็วลม'] = data_features_d['ความเร็วลม'].astype(float)
data_features_d['จำนวนเมฆ'] = data_features_d['จำนวนเมฆ'].astype(float)
data_features_d['ปริมาณฝน'] = data_features_d['ปริมาณฝน'].astype(float)
data_features_d['อุณหภูมิต่ำสุด'] = data_features_d['อุณหภูมิต่ำสุด'].astype(float)
# Out:
# <ipython-input-38-5845645da5f4>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_features_d['ความเร็วลม'] = data_features_d['ความเร็วลม'].astype(float)
# <ipython-input-38-5845645da5f4>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_features_d['จำนวนเมฆ'] = data_features_d['จำนวนเมฆ'].astype(float)
# <ipython-input-38-5845645da5f4>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
data_features_d.describe()
# Out:
#             ความกด  ความชื้นสัมพัทธ์  อุณหภูมิตุ้มแห้ง  อุณหภูมิจุดน้ำค้าง  \
# count  5061.000000       5061.000000       5061.000000         5061.000000
# mean   1012.731324         70.438253         25.002667           18.420944
# std       3.158633          9.433792          2.720534            3.630472
# min    1002.040000         38.000000         11.800000            1.500000
# 25%    1010.760000         64.000000         23.500000           16.100000
# 50%    1012.610000         69.000000         25.400000           18.500000
# 75%    1014.710000         77.000000         26.900000           21.200000
# max    1026.100000         99.000000         31.000000           28.400000
#
#        อุณหภูมิต่ำสุด     จำนวนเมฆ     ปริมาณฝน   ความเร็วลม
# count     5061.000000  5061.000000  5061.000000  5061.000000
# mean        19.933570     3.308832     1.556194     2.284726
# std          3.295887     2.494353     6.816712     1.209540
# ...

# %%
import matplotlib
matplotlib.rcParams['figure.figsize']=[10,6]

# %%
pd.plotting.scatter_matrix(data_features_d);
# Out:
# /usr/local/lib/python3.8/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 3588 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.8/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 3623 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.8/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 3634 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.8/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 3617 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.8/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 3585 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# ...

# %%
from matplotlib import pyplot as plt

# %%
plt.hist(data_features_d['ความกด']);

# %%
from sklearn import preprocessing

# %% [markdown]
# ### Standard scaler

# %%
#define
scaler = preprocessing.StandardScaler()
#train
scaler.fit(data_features_d)
#predict-transform
data_features_d_s = scaler.transform(data_features_d)

# %%
data_features_d_s
# Out:
# array([[-2.29910857,  1.33170074,  0.95480871, ...,  2.28184617,
#         -0.02291572,  0.5914187 ],
#        [-1.92549238,  2.28581221,  0.21958617, ...,  2.68279133,
#          2.36850273, -0.23542385],
#        [-1.65952832,  1.64973789,  0.21958617, ...,  2.68279133,
#          0.21182474,  0.5914187 ],
#        ...,
#        [-2.49224914, -1.63664607,  0.47691406, ..., -1.32666027,
#         -0.22831362, -0.23542385],
#        [-2.20728764, -1.53063368,  0.07254167, ..., -0.52476995,
#         -0.22831362, -1.06226641],
#        [-1.43155912, -1.31860891,  0.21958617, ..., -0.92571511,
#         -0.22831362, -1.06226641]])

# %%
plt.hist(data_features_d_s[:,0])
# Out:
# (array([  29.,  136.,  466., 1269., 1579.,  986.,  450.,  118.,   19.,
#            9.]),
#  array([-3.3851285 , -2.62333143, -1.86153436, -1.09973729, -0.33794022,
#          0.42385684,  1.18565391,  1.94745098,  2.70924805,  3.47104512,
#          4.23284218]),
#  <a list of 10 Patch objects>)

# %%
plt.subplot(1,2,1)
plt.hist(data_features_d['ความกด'])
plt.subplot(1,2,2)
plt.hist(data_features_d_s[:,0]);

# %%
plt.subplot(1,2,1)
plt.hist(data_features_d['ปริมาณฝน'])
plt.subplot(1,2,2)
plt.hist(data_features_d_s[:,4]);

# %% [markdown]
# ### Min-max normalization

# %%
#define
scaler = preprocessing.MinMaxScaler()
#train
scaler.fit(data_features_d)
#predict-transform
data_features_d_norm = scaler.transform(data_features_d)

# %%
plt.subplot(1,3,1)
plt.hist(data_features_d['ความกด'])
plt.subplot(1,3,2)
plt.hist(data_features_d_s[:,0])
plt.subplot(1,3,3)
plt.hist(data_features_d_norm[:,0]);

# %% [markdown]
# # Discritization

# %%
home_data = pd.read_csv('/content/drive/MyDrive/2 65/จารต้น 2/bsc_DMPM_data/ส่ง data บ้าน/17ธนภรณ์ บุญหลักคำ.csv')

# %%
home_data.head()
# Out:
#    post_id  number_of_rai  number_of_ngan  number_of_va  number_of_story  \
# 0     25.0            0.0             0.0          63.8              1.0
# 1     33.0            0.0             0.0          61.1              1.0
# 2    495.0            NaN             3.0          12.8              NaN
# 3    564.0            NaN             NaN          85.0              NaN
# 4    566.0            NaN             NaN          65.0              NaN
#
#    number_of_bedroom  number_of_bathroom  direction  furniture  usable_area  \
# 0                3.0                 2.0        0.0        0.0        135.0
# 1                2.0                 2.0        0.0        0.0        112.0
# 2                0.0                 NaN        0.0        0.0          0.0
# 3                0.0                 NaN        0.0        0.0          0.0
# 4                0.0                 NaN        0.0        0.0          0.0
#
# ...

# %%
home_data.shape
# Out:
# (100, 22)

# %% [markdown]
# ### ลบ record ที่ ค่า sell price เป็นค่าว่าง

# %%
home_data = home_data.dropna(subset=['sell_price'])

# %%
plt.hist(home_data['sell_price']);

# %% [markdown]
# ### แปลงค่า sell_price
# - ราคาต่ำกว่า 5m ให้เป็น 1
# - ราคาระหว่าง 5m-10m ให้เป็น 2
# - ราคา 10m ขึ้นไป ให้เป็น 3

# %%
home_data1 = home_data[home_data['sell_price']<=5000000]
home_data2 = home_data[(home_data['sell_price']>5000000) & (home_data['sell_price']<10000000)]
home_data3 = home_data[home_data['sell_price']>=10000000]

# %%
home_data1.shape
# Out:
# (76, 22)

# %%
home_data1['sell_price_class'] = 1
home_data2['sell_price_class'] = 2
home_data3['sell_price_class'] = 3
# Out:
# <ipython-input-59-b13373dc2aa1>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   home_data1['sell_price_class'] = 1
# <ipython-input-59-b13373dc2aa1>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   home_data2['sell_price_class'] = 2
# <ipython-input-59-b13373dc2aa1>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
home_data = pd.concat([home_data1,home_data2,home_data3])

# %%
home_data
# Out:
#     post_id  number_of_rai  number_of_ngan  number_of_va  number_of_story  \
# 0      25.0            0.0             0.0          63.8              1.0
# 1      33.0            0.0             0.0          61.1              1.0
# 3     564.0            NaN             NaN          85.0              NaN
# 4     566.0            NaN             NaN          65.0              NaN
# 9     656.0            NaN             NaN          60.0              NaN
# ..      ...            ...             ...           ...              ...
# 96  19496.0            0.0             2.0          56.8              1.0
# 8     634.0            1.0             NaN           NaN              NaN
# 40   3622.0            0.0             1.0          69.0              2.0
# 45   5978.0            0.0             1.0           1.0              NaN
# 73  12759.0            0.0             1.0          58.0              2.0
#
#     number_of_bedroom  number_of_bathroom  direction  furniture  usable_area  \
# ...

# %%
plt.hist(home_data['sell_price_class'])
# Out:
# (array([76.,  0.,  0.,  0.,  0., 20.,  0.,  0.,  0.,  4.]),
#  array([1. , 1.2, 1.4, 1.6, 1.8, 2. , 2.2, 2.4, 2.6, 2.8, 3. ]),
#  <a list of 10 Patch objects>)

# %%
home_data[home_data['sell_price']<500000]=1

# %%
home_data
# Out:
#     post_id  number_of_rai  number_of_ngan  number_of_va  number_of_story  \
# 0      25.0            0.0             0.0          63.8              1.0
# 1      33.0            0.0             0.0          61.1              1.0
# 3     564.0            NaN             NaN          85.0              NaN
# 4     566.0            NaN             NaN          65.0              NaN
# 9     656.0            NaN             NaN          60.0              NaN
# ..      ...            ...             ...           ...              ...
# 96  19496.0            0.0             2.0          56.8              1.0
# 8     634.0            1.0             NaN           NaN              NaN
# 40   3622.0            0.0             1.0          69.0              2.0
# 45   5978.0            0.0             1.0           1.0              NaN
# 73  12759.0            0.0             1.0          58.0              2.0
#
#     number_of_bedroom  number_of_bathroom  direction  furniture  usable_area  \
# ...

# %%
price_under=home_data[home_data['sell_price']<5000000]
price_under.insert(22,'price_class','1')
price_under
# Out:
#     post_id  number_of_rai  number_of_ngan  number_of_va  number_of_story  \
# 0      25.0            0.0             0.0          63.8              1.0
# 1      33.0            0.0             0.0          61.1              1.0
# 3     564.0            NaN             NaN          85.0              NaN
# 4     566.0            NaN             NaN          65.0              NaN
# 9     656.0            NaN             NaN          60.0              NaN
# ..      ...            ...             ...           ...              ...
# 92  19483.0            0.0             0.0          59.9              2.0
# 93  19492.0            0.0             0.0          90.3              2.0
# 97  20164.0            0.0             1.0           2.0              1.0
# 98     31.0            0.0             0.0          55.8              2.0
# 99    570.0            0.0             0.0          83.0              NaN
#
#     number_of_bedroom  number_of_bathroom  direction  furniture  usable_area  \
# ...

# %%
home_data['grade']=''
home_data['grade'][(home_data['sell_price']>10000000)]=3
# Out:
# <ipython-input-66-baa8748ddb07>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   home_data['grade'][(home_data['sell_price']>10000000)]=3

# %%
home_data
# Out:
#     post_id  number_of_rai  number_of_ngan  number_of_va  number_of_story  \
# 0      25.0            0.0             0.0          63.8              1.0
# 1      33.0            0.0             0.0          61.1              1.0
# 3     564.0            NaN             NaN          85.0              NaN
# 4     566.0            NaN             NaN          65.0              NaN
# 9     656.0            NaN             NaN          60.0              NaN
# ..      ...            ...             ...           ...              ...
# 96  19496.0            0.0             2.0          56.8              1.0
# 8     634.0            1.0             NaN           NaN              NaN
# 40   3622.0            0.0             1.0          69.0              2.0
# 45   5978.0            0.0             1.0           1.0              NaN
# 73  12759.0            0.0             1.0          58.0              2.0
#
#     number_of_bedroom  number_of_bathroom  direction  furniture  usable_area  \
# ...

# %%
def filter(x):
    if x < 5000000:
        return "1"
    if x > 10000000:
        return "3"

# %%
home_data['new_class'] = home_data['sell_price'].apply(filter)

# %%
home_data
# Out:
#     post_id  number_of_rai  number_of_ngan  number_of_va  number_of_story  \
# 0      25.0            0.0             0.0          63.8              1.0
# 1      33.0            0.0             0.0          61.1              1.0
# 3     564.0            NaN             NaN          85.0              NaN
# 4     566.0            NaN             NaN          65.0              NaN
# 9     656.0            NaN             NaN          60.0              NaN
# ..      ...            ...             ...           ...              ...
# 96  19496.0            0.0             2.0          56.8              1.0
# 8     634.0            1.0             NaN           NaN              NaN
# 40   3622.0            0.0             1.0          69.0              2.0
# 45   5978.0            0.0             1.0           1.0              NaN
# 73  12759.0            0.0             1.0          58.0              2.0
#
#     number_of_bedroom  number_of_bathroom  direction  furniture  usable_area  \
# ...

# %%
home_data.loc[home_data['sell_price']<5000000,'sellpriceclass']=1

# %%
import numpy as np

# %%
np.where(home_data['sell_price']<5000000,1,home_data['sell_price'])
# Out:
# array([1.0000e+00, 1.0000e+00, 1.0000e+00, 1.0000e+00, 1.0000e+00,
#        1.0000e+00, 1.0000e+00, 1.0000e+00, 1.0000e+00, 1.0000e+00,
#        1.0000e+00, 1.0000e+00, 1.0000e+00, 1.0000e+00, 1.0000e+00,
#        1.0000e+00, 1.0000e+00, 1.0000e+00, 1.0000e+00, 1.0000e+00,
#        1.0000e+00, 1.0000e+00, 1.0000e+00, 1.0000e+00, 1.0000e+00,
#        1.0000e+00, 1.0000e+00, 1.0000e+00, 1.0000e+00, 1.0000e+00,
#        1.0000e+00, 1.0000e+00, 1.0000e+00, 1.0000e+00, 1.0000e+00,
#        1.0000e+00, 1.0000e+00, 1.0000e+00, 1.0000e+00, 1.0000e+00,
#        1.0000e+00, 1.0000e+00, 1.0000e+00, 1.0000e+00, 1.0000e+00,
#        1.0000e+00, 1.0000e+00, 1.0000e+00, 1.0000e+00, 1.0000e+00,
#        1.0000e+00, 1.0000e+00, 1.0000e+00, 1.0000e+00, 1.0000e+00,
#        1.0000e+00, 1.0000e+00, 1.0000e+00, 1.0000e+00, 1.0000e+00,
#        1.0000e+00, 1.0000e+00, 1.0000e+00, 1.0000e+00, 1.0000e+00,
#        5.0000e+06, 1.0000e+00, 1.0000e+00, 1.0000e+00, 1.0000e+00,
# ...

# %%
x=home_data[['sell_price']]

# %%
a = x[(x['sell_price']<=5000000)]

# %%
a
# Out:
#     sell_price
# 0    2700000.0
# 1    2600000.0
# 3    4400000.0
# 4    2750000.0
# 9    4070000.0
# ..         ...
# 92   4235000.0
# 93   4707000.0
# 97   2990000.0
# 98   4000000.0
# 99   1375000.0
#
# [76 rows x 1 columns]

# %%
a.iloc[0:76]=1
# Out:
# /usr/local/lib/python3.8/dist-packages/pandas/core/indexing.py:1732: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)
# /usr/local/lib/python3.8/dist-packages/pandas/core/indexing.py:723: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value, self.name)

# %%
a
# Out:
#     sell_price
# 0          1.0
# 1          1.0
# 3          1.0
# 4          1.0
# 9          1.0
# ..         ...
# 92         1.0
# 93         1.0
# 97         1.0
# 98         1.0
# 99         1.0
#
# [76 rows x 1 columns]

# %%
home_data['XX']=a['sell_price']

# %%
home_data
# Out:
#     post_id  number_of_rai  number_of_ngan  number_of_va  number_of_story  \
# 0      25.0            0.0             0.0          63.8              1.0
# 1      33.0            0.0             0.0          61.1              1.0
# 3     564.0            NaN             NaN          85.0              NaN
# 4     566.0            NaN             NaN          65.0              NaN
# 9     656.0            NaN             NaN          60.0              NaN
# ..      ...            ...             ...           ...              ...
# 96  19496.0            0.0             2.0          56.8              1.0
# 8     634.0            1.0             NaN           NaN              NaN
# 40   3622.0            0.0             1.0          69.0              2.0
# 45   5978.0            0.0             1.0           1.0              NaN
# 73  12759.0            0.0             1.0          58.0              2.0
#
#     number_of_bedroom  number_of_bathroom  direction  furniture  usable_area  \
# ...

# %% [markdown]
# # one-hot-encoder

# %%
home_data_dummies = pd.get_dummies(home_data,columns=['zone'])

# %%
home_data_dummies
# Out:
#     post_id  number_of_rai  number_of_ngan  number_of_va  number_of_story  \
# 0      25.0            0.0             0.0          63.8              1.0
# 1      33.0            0.0             0.0          61.1              1.0
# 3     564.0            NaN             NaN          85.0              NaN
# 4     566.0            NaN             NaN          65.0              NaN
# 9     656.0            NaN             NaN          60.0              NaN
# ..      ...            ...             ...           ...              ...
# 96  19496.0            0.0             2.0          56.8              1.0
# 8     634.0            1.0             NaN           NaN              NaN
# 40   3622.0            0.0             1.0          69.0              2.0
# 45   5978.0            0.0             1.0           1.0              NaN
# 73  12759.0            0.0             1.0          58.0              2.0
#
#     number_of_bedroom  number_of_bathroom  direction  furniture  usable_area  \
# ...
